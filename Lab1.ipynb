# %% [markdown]
# <a href="https://colab.research.google.com/github/jjchandru/BP-DL10005-90-13/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 10
print("Age is", age)

print("This is a revised version.")
# Out:
# Age is 10
# This is a revised version.
